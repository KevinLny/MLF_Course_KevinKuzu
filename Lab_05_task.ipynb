# %% [markdown]
# # MPA-MLF, Lab 5 - Feedforward Neural Networks

# %% [markdown]
# These exercises are focused on dealing with neural networks. It is strongly recommended to use google collab for these pc labs. Why? Google collab offers a free GPU capacity to train machine learning models. Training NN on GPU can drastically speed up the training process. You can turn on the GPU accelerator in: Runtime -> Change runtime type -> GPU,

# %% [markdown]
# ## The basic terminology

# %% [markdown]
# ### Neural Networks

# %% [markdown]
# Think of a neural network as a complex web of neurons (or nodes) that are interconnected to process information, similar to how the human brain works. Each neuron in this network can receive inputs, process them, and pass on the output to other neurons. The goal of a neural network is to transform the inputs (e.g., images, texts, numbers) into a desired output (e.g., identifying what's in an image, translating text, etc.).

# %% [markdown]
# ![title](img/network.png)

# %% [markdown]
# ### Layers

# %% [markdown]
# A neural network is made up of layers: the input layer (where the data enters the network), one or more hidden layers (where most of the processing happens), and the output layer (where the final prediction is made). You can think of each layer as a filter that increasingly refines the information as it passes through the network. In our case, we will discuss feedforward, fully-connected neural networks. Fully connected means that every neuron in layer *n* is connected by a weighted connection with all neurons in the layers *n+1*. Feedforward means that data are passed in one direction only, there are no reccurent connections (feedback loops) exist.

# %% [markdown]
# ![title](img/Neural_network.png)

# %% [markdown]
# ### Neuron

# %% [markdown]
# A neuron, or node, is the basic unit of a neural network. It receives input, applies a weight (significance) to that input, adds a bias (a constant value to ensure the neuron activates correctly), and then uses an activation function to determine whether and how strongly to pass its signal to the next layer. Each neuron contributes to the network's ability to make accurate predictions or decisions.|

# %% [markdown]
# ![title](img/neuron.png)

# %% [markdown]
# ### Neuron in the input layer

# %% [markdown]
# In the input layer the input neurons are composed of identity only, that means everying that comes to the input comes directly to the output

# %% [markdown]
# ### Training

# %% [markdown]
# Training a neural network involves feeding it with data for which the correct output is known, allowing the network to adjust its weights and biases to minimize the difference between its predictions and the actual truths. This process is repeated numerous times with many data examples.

# %% [markdown]
# ### Loss Function

# %% [markdown]
# A loss function measures how well the neural network is performing, meaning how close or far its predictions are from the actual values. The goal of training is to minimize this loss, or error, making the network's predictions as accurate as possible.

# %% [markdown]
# ## Exercise 1 - XOR problem

# %% [markdown]
# During the last lecture, we saw that the single perceptron model with a step function could be used only for solving linearly-separable classification problems. Because of that, a single perceptron can not be trained to be able to behave like an XOR gate. To approximate the XOR gate using a neural network, we need to use the following structure:

# %% [markdown]
# ![nn.png](data:image/png;base64,...)

# %% [markdown]
# The above structure contains three layers: two neurons in the input layer (blue), two in the hidden layer and one in the output layer (yellow). The input layer represents the identity functions (the outputs are equal to the inputs)

# %% [markdown]
# We will use *Keras* API to build and train our neural network. Keras is an open-source neural network library written in Python. It is designed to enable fast experimentation with deep neural networks and provides a high-level API for building and training neural networks.

# %% [markdown]
# ### 0. First import libraries

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 1. prepare data

# %% [markdown]
# In this part, the task would be to prepade our dataset, basically it is the logic table for *XOR* function

# %%
X = [[0, 0], [0, 1], [1, 0], [1, 1]]
y = [0, 1, 1, 0]

# %% [markdown]
# ### 2. Creating the model

# %% [markdown]
# To create a model of NN that is in the picture above, run the following cell

# %%
model = Sequential()
model.add(InputLayer(input_shape=(2,)))
model.add(Dense(2, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# **Sequential** is a model type used in Keras for building feedforward neural networks. It is called "sequential" because the layers are stacked sequentially on top of each other, and the output of one layer is passed as input to the next layer.
#
# To create a sequential model, instantiate a Sequential object and then add layers to it using the **add()** method. There are many layers that Keras offers. We will use *Dense layer*
#
# **Dense layer** represents a fully connected layer, which means that every neuron in the layer is connected to every neuron in the previous layer. In each layer, we will specify an activation function and the number of neurons that layer contains. The input layer is not defined as a dense layer, but instead of that, we will specify the *input_dim* parameter in the layer that follows the input layer. *input_dim* parameter specifies the number of neurons in the input layer

# %% [markdown]
# ### 3. Compile the model

# %% [markdown]
# To compile yor model run:

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# **keras.complile()** is used to configure the learning process before training the model.
# We need to specify 3 parameters:
# - *loss*, *optimizer* and *metrics*
#
# - as our loss function (error function/objective function), we will choose *binary_crossentropy* - loss function often used for binary classification
#
# - *optimizer* is optimization algorithm used for optimizing weights in our training process, we will choose *stochastic gradient descent*
#
# - *metrics* is metric user for model evaluation

# %% [markdown]
# ### 4. Model training

# %% [markdown]
# In the lecture, we talked about training the Multi-layer perceptron. The training process consists of the following steps:
#
# 1. Weight initialization
# 2. Forward Propagation
# 3. Compute Loss
# 4. Backpropagation
# 5. Update Weights
# 6. Repeat 2->6 until maximum epochs are reached
#
# When training a machine learning model, the training data is usually divided into batches (parts), and the model updates its weights after processing each batch. The batch size determines how many training examples are included in each batch.
#
# For example, we have 10,000 training examples and a batch size of 100. In this case, the training data would be divided into 100 batches of 100 examples each. During training, the model would process each batch, calculate the loss or error, and update its weights based on the average of the errors in that batch. In other words, if we batch equal to 1. we will update the weights 10 000 times. If we have batch size == 100, we will update the weights only 100 times

# %% [markdown]
# To train your model, run the following line of the code:

# %%
X = np.array(X)
y = np.array(y)
history = model.fit(X, y, epochs=500, batch_size=1) # I did 500 because with more it crash
# Out:
# Epoch 1/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5000 - loss: 0.7250
# Epoch 2/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7248
# Epoch 3/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7244
# Epoch 4/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7235
# Epoch 5/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7238
# Epoch 6/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7230
# Epoch 7/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7233
# Epoch 8/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7224
# Epoch 9/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7228
# Epoch 10/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2500 - loss: 0.7225
# Epoch 11/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7224
# Epoch 12/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7215
# Epoch 13/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7219
# Epoch 14/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7217
# Epoch 15/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7209
# Epoch 16/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7212
# Epoch 17/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7211
# Epoch 18/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7209
# Epoch 19/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7201
# Epoch 20/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7205
# Epoch 21/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7203
# Epoch 22/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7195
# Epoch 23/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7199
# Epoch 24/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7197
# Epoch 25/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7195
# Epoch 26/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7188
# Epoch 27/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7187
# Epoch 28/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7191
# Epoch 29/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7184
# Epoch 30/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2500 - loss: 0.7181
# Epoch 31/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7180
# Epoch 32/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5000 - loss: 0.7185
# Epoch 33/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7183
# Epoch 34/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7181
# Epoch 35/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7175
# Epoch 36/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7178
# Epoch 37/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7177
# Epoch 38/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7175
# Epoch 39/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7168
# Epoch 40/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7173
# Epoch 41/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7171
# Epoch 42/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7164
# Epoch 43/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7169
# Epoch 44/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2500 - loss: 0.7162
# Epoch 45/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7167
# Epoch 46/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7165
# Epoch 47/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7159
# Epoch 48/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.7163
# Epoch 49/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7162
# Epoch 50/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7161
# Epoch 51/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2500 - loss: 0.7160
# Epoch 52/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7158
# Epoch 53/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7152
# Epoch 54/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5000 - loss: 0.7157
# Epoch 55/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7150
# Epoch 56/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7149
# Epoch 57/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7154
# Epoch 58/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7153
# Epoch 59/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7151
# Epoch 60/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7144
# Epoch 61/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7143
# Epoch 62/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2500 - loss: 0.7148
# Epoch 63/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7148
# Epoch 64/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7140
# Epoch 65/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2500 - loss: 0.7145
# Epoch 66/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5000 - loss: 0.7144
# Epoch 67/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5000 - loss: 0.7143
# Epoch 68/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7143
# Epoch 69/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7136
# Epoch 70/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7135
# Epoch 71/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2500 - loss: 0.7140
# Epoch 72/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5000 - loss: 0.7139
# Epoch 73/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5000 - loss: 0.7132
# Epoch 74/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5000 - loss: 0.7138
# Epoch 75/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7136
# Epoch 76/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2500 - loss: 0.7130
# Epoch 77/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2500 - loss: 0.7129
# Epoch 78/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5000 - loss: 0.7128
# Epoch 79/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2500 - loss: 0.7133
# Epoch 80/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2500 - loss: 0.7132
# Epoch 81/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2500 - loss: 0.7131
# Epoch 82/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5000 - loss: 0.7131
# Epoch 83/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5000 - loss: 0.7130
# Epoch 84/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5000 - loss: 0.7124
# Epoch 85/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5000 - loss: 0.7129
# Epoch 86/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5000 - loss: 0.7128
# Epoch 87/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2500 - loss: 0.7127
# Epoch 88/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5000 - loss: 0.7126
# Epoch 89/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2500 - loss: 0.7120
# Epoch 90/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2500 - loss: 0.7119
# Epoch 91/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2500 - loss: 0.7124
# Epoch 92/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2500 - loss: 0.7123
# Epoch 93/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2500 - loss: 0.7123
# Epoch 94/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2500 - loss: 0.7116
# Epoch 95/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5000 - loss: 0.7115
# Epoch 96/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2500 - loss: 0.7120
# Epoch 97/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2500 - loss: 0.7120
# Epoch 98/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7500 - loss: 0.7113
# Epoch 99/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5000 - loss: 0.7113
# Epoch 100/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7118
# Epoch 101/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2500 - loss: 0.7117
# Epoch 102/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2500 - loss: 0.7116
# Epoch 103/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.
# Epoch 475/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7500 - loss: 0.6169
# Epoch 476/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7500 - loss: 0.6159
# Epoch 477/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7500 - loss: 0.6157
# Epoch 478/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7500 - loss: 0.6151
# Epoch 479/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7500 - loss: 0.6145
# Epoch 480/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7500 - loss: 0.6139
# Epoch 481/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7500 - loss: 0.6129
# Epoch 482/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7500 - loss: 0.6126
# Epoch 483/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7500 - loss: 0.6120
# Epoch 484/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7500 - loss: 0.6115
# Epoch 485/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7500 - loss: 0.6106
# Epoch 486/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7500 - loss: 0.6099
# Epoch 487/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7500 - loss: 0.6096
# Epoch 488/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7500 - loss: 0.6091
# Epoch 489/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7500 - loss: 0.6085
# Epoch 490/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7500 - loss: 0.6075
# Epoch 491/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7500 - loss: 0.6073
# Epoch 492/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7500 - loss: 0.6067
# Epoch 493/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7500 - loss: 0.6060
# Epoch 494/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7500 - loss: 0.6054
# Epoch 495/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7500 - loss: 0.6048
# Epoch 496/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7500 - loss: 0.6042
# Epoch 497/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7500 - loss: 0.6036
# Epoch 498/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7500 - loss: 0.6031
# Epoch 499/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7500 - loss: 0.6024
# Epoch 500/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7500 - loss: 0.6018

# %% [markdown]
# the method **.fit()**, is used to train the model. We can see that it takes several input parameters:
#  - *X* - input data
#  - *y* - label for the input data
#  - *epochs* number of training epochs (iterations)
#  - *batch_size* - number of samples in each batch
#  - *verbose* - set verbose parameter to see the progress of loss and metrics during the training epochs
#
# These are not the only parameters the .fit() method can take. Check official documentation: https://keras.io/api/models/model_training_apis/
#
# We will set the output of our .fit() function to variable *history*, where the loss and other metrics defined above in the .compile() function during the training are saved.

# %% [markdown]
# ### 5. Model evaluation

# %% [markdown]
# Out training process is finished. To evaluate the performance of our model on test data, tun the following cell of the code:

# %%
loss, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: {:.2f}'.format(accuracy*100))
# Out:
# Accuracy: 75.00

# %% [markdown]
# ### 6. Model predictions

# %%
for id_x, data_sample in enumerate(X):
  sample_reshaped = np.array([data_sample])

  prediction = model.predict(sample_reshaped, verbose=0)

  print(f"Data sample is {data_sample}, prediction {prediction[0]}, ground_truth {y[id_x]}")
# Out:
# Data sample is [0 0], prediction [0.28329635], ground_truth 0
# Data sample is [0 1], prediction [0.57540417], ground_truth 1
# Data sample is [1 0], prediction [0.5556101], ground_truth 1
# Data sample is [1 1], prediction [0.58422804], ground_truth 0

# %% [markdown]
# ### 7. Display loss function during the training process and acuracy

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.xlabel('n epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ### TASK:
#
# In this part of the exercise, the task would be to play around with the code above to see the influence of hyperparameters.
#
# As we know from the lecture, neural networks contain two types of parameters:
#   1. **Learnable parameters** - *weights* and *biases*. these parameters are adjusted in the training process.
#   2. **Non-learnable parameters (hyperparameters)** - learning_rate, number_of_neurons, number_of_layers, number_of_epochs, type of activation functions in the neurons.., basically any user-defined setting is considered to be hyperparameter
#
#
# Change the following parameters:
# - number of epochs
# - learning_rate
# - activation functions in layers,
# - batch_size,
# - verbose,
# - number of neurons in the hidden layer
#
# Moreover, see the influence on the training process and results.
#
# **Note: Every time we change some hyper-parameters, do not forget to compile the model, to initialize the learnable parameters again**

# %% [markdown]
# ## Exercise 2 - Congressional Voting Data
#
# In the attached dataset, results from congressional voting can be found. Your task is to train a model that can recognize that the politician is *republican* or *democrat* based on voting results. We would follow the general machine learning steps that were described in the lecture.

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Loading dataset

# %% [markdown]
# **First mount your google drive to google colab file.**

# %%
path_to_dataset = 'voting_complete.csv' # change the PATH
pd_dataset = pd.read_csv(path_to_dataset)

# %%
pd_dataset
# Out:
#      Unnamed: 0  Class Name handicapped-infants water-project-cost-sharing  \
# 0             0  republican                   n                          y
# 1             1  republican                   n                          y
# 2             2    democrat                   ?                          y
# 3             3    democrat                   n                          y
# 4             4    democrat                   y                          y
# ..          ...         ...                 ...                        ...
# 430         430  republican                   n                          n
# 431         431    democrat                   n                          n
# 432         432  republican                   n                          ?
# 433         433  republican                   n                          n
# 434         434  republican                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   n                    y               y
# 2                                   y                    ?               y
# 3                                   y                    n               ?
# 4                                   y                    n               y
# ..                                ...                  ...             ...
# 430                                 y                    y               y
# 431                                 y                    n               n
# 432                                 n                    y               y
# 433                                 n                    y               y
# 434                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 430                           y                       n
# 431                           n                       y
# 432                           y                       n
# 433                           y                       ?
# 434                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 430                         n          y           y
# 431                         y          y           y
# 432                         n          n           n
# 433                         ?          ?           ?
# 434                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              ?                  y                      y
# 1                              n                  y                      y
# 2                              y                  n                      y
# 3                              y                  n                      y
# 4                              y                  ?                      y
# ..                           ...                ...                    ...
# 430                            n                  y                      y
# 431                            n                  n                      n
# 432                            y                  y                      y
# 433                            n                  y                      y
# 434                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       y                 n                                      ?
# 2       y                 n                                      n
# 3       n                 n                                      y
# 4       y                 y                                      y
# ..    ...               ...                                    ...
# 430     y                 n                                      y
# 431     n                 n                                      y
# 432     y                 n                                      y
# 433     y                 n                                      y
# 434     y                 ?                                      n
#
# [435 rows x 18 columns]

# %% [markdown]
# ### 2. Train/Test Split

# %% [markdown]
# Fistlty we need to split our dataset into train and test. We will use 80% of dataset as our trainset and 20% od dataset as our testset. You can use functions included in *keras*, *scikit-learn*, or you can write your own:

# %%
# define a function for train and test split

def train_test_split(pd_data: pd.DataFrame, test_ratio: float = 0.2) -> tuple:
    pd_dataset = pd_data.copy()
    pd_dataset = pd_dataset[pd_dataset.columns[1:]]
    index = np.arange(len(pd_dataset))
    index = np.random.permutation(index)
    train_ammount = int(len(index)*test_ratio)
    train_ids = index[train_ammount:]
    test_ids = index[:train_ammount]

    train_dataset = pd_dataset[pd_dataset.index.isin(train_ids)].reset_index()
    test_dataset = pd_dataset[pd_dataset.index.isin(test_ids)].reset_index()

    train_dataset = train_dataset[train_dataset.columns[1:]]
    test_dataset = test_dataset[test_dataset.columns[1:]]

    return train_dataset[train_dataset.columns[1:]], train_dataset[train_dataset.columns[0]], test_dataset[test_dataset.columns[1:]], test_dataset[test_dataset.columns[0]]

# %%
x_train, y_train, x_test, y_test = train_test_split(pd_dataset)

# %% [markdown]
# ### 3. Data examination

# %% [markdown]
# The task would be to examine the dataset. Check:
#
# 1. Is it a classification of regression task?
# 2. How many data samples do we have?
# 3. How many features do we have?
# 4. What data types do we have in our dataset?
# 5. Are there any missing values?
# 6. How many labels do we have?

# %%
x_train
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 0                     n                          y
# 1                     n                          y
# 2                     ?                          y
# 3                     n                          y
# 4                     y                          y
# ..                  ...                        ...
# 343                   n                          n
# 344                   n                          n
# 345                   n                          ?
# 346                   n                          n
# 347                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   n                    y               y
# 2                                   y                    ?               y
# 3                                   y                    n               ?
# 4                                   y                    n               y
# ..                                ...                  ...             ...
# 343                                 y                    y               y
# 344                                 y                    n               n
# 345                                 n                    y               y
# 346                                 n                    y               y
# 347                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 343                           y                       n
# 344                           n                       y
# 345                           y                       n
# 346                           y                       ?
# 347                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 343                         n          y           y
# 344                         y          y           y
# 345                         n          n           n
# 346                         ?          ?           ?
# 347                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              ?                  y                      y
# 1                              n                  y                      y
# 2                              y                  n                      y
# 3                              y                  n                      y
# 4                              y                  ?                      y
# ..                           ...                ...                    ...
# 343                            n                  y                      y
# 344                            n                  n                      n
# 345                            y                  y                      y
# 346                            n                  y                      y
# 347                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       y                 n                                      ?
# 2       y                 n                                      n
# 3       n                 n                                      y
# 4       y                 y                                      y
# ..    ...               ...                                    ...
# 343     y                 n                                      y
# 344     n                 n                                      y
# 345     y                 n                                      y
# 346     y                 n                                      y
# 347     y                 ?                                      n
#
# [348 rows x 16 columns]

# %%
y_train_num = y_train.replace({'republican': 0, 'democrat': 1}).values.astype('float32')
y_test_num = y_test.replace({'republican': 0, 'democrat': 1}).values.astype('float32')
# Out:
# /tmp/ipykernel_16205/3862093427.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y_train_num = y_train.replace({'republican': 0, 'democrat': 1}).values.astype('float32')
# /tmp/ipykernel_16205/3862093427.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y_test_num = y_test.replace({'republican': 0, 'democrat': 1}).values.astype('float32')

# %% [markdown]
# ### 4. Data preprocessing

# %% [markdown]
# When you preprocess your traing data, do not forget that you need to apply the same preprocessing also for your test set. For example: If you decide to delete some columns in your train set, you have to delete the same columns in your test set.

# %% [markdown]
# Possible preprocessing steps (try several and see the influence of your preprocessing on your results)
#  - Replace missing values with any data imputation technique ( for example, the most occurring value in the column), then perform one-hot encoding or label encoding of your data
#  - Consider the missing value to be the third category 'unknown' and then perform one-hot encoding or label encoding
#
# The target value also has to be encoded. This can be done by one-hot encoding or label encoding.

# %%
#WRITE YOUR CODE HERE
y_train_num = y_train.replace({'republican': 0, 'democrat': 1}).values
y_test_num = y_test.replace({'republican': 0, 'democrat': 1}).values

def preprocess(df):
    df_copy = df.copy()
    df_copy.replace('?', np.nan, inplace=True)
    df_copy.fillna(df_copy.mode().iloc[0], inplace=True)
    return pd.get_dummies(df_copy)

x_train_final = preprocess(x_train)
x_test_final = preprocess(x_test)

x_test_final = x_test_final.reindex(columns=x_train_final.columns, fill_value=0)

x_train_np = x_train_final.values.astype('float32')
x_test_np = x_test_final.values.astype('float32')
# Out:
# /tmp/ipykernel_16205/1615722700.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y_train_num = y_train.replace({'republican': 0, 'democrat': 1}).values
# /tmp/ipykernel_16205/1615722700.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y_test_num = y_test.replace({'republican': 0, 'democrat': 1}).values

# %% [markdown]
# ### 5. Creating the model

# %% [markdown]
# 1. Create your model using alteast one hidden layer.
#
# *hint: do not create too complex models, this is a very simple task, so it would be enought to use just few neurons in the hidden layers*

# %%
input_dim = x_train_np.shape[1]

model = Sequential()
model.add(InputLayer(shape=(input_dim,)))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# 2. Check what *model.summary()* does

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 545 (2.13 KB)
#  Trainable params: 545 (2.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 3. Compile the model, choose a suitable loss function, choose gradient to descend optimizer and specify the learning rate, and choose accuracy as our metric

# %%
# WRITE YOUR CODE HERE
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# 4. Train the model. Specify the number of epochs and batch size. Now is the time to create a validation dataset. Set 20% of dataset to be a validation dataset

# %%
#cWRITE YOUR CODE HERE
history = model.fit(x_train_np, y_train_num, epochs=50, batch_size=8, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8309 - loss: 0.4316 - val_accuracy: 0.8143 - val_loss: 0.4231
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9029 - loss: 0.3158 - val_accuracy: 0.8429 - val_loss: 0.3662
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9101 - loss: 0.2588 - val_accuracy: 0.8429 - val_loss: 0.3379
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9137 - loss: 0.2240 - val_accuracy: 0.8714 - val_loss: 0.3143
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9173 - loss: 0.1972 - val_accuracy: 0.8714 - val_loss: 0.3058
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9173 - loss: 0.1764 - val_accuracy: 0.9000 - val_loss: 0.2922
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9317 - loss: 0.1559 - val_accuracy: 0.9000 - val_loss: 0.2826
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9388 - loss: 0.1409 - val_accuracy: 0.9000 - val_loss: 0.2736
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9424 - loss: 0.1282 - val_accuracy: 0.9000 - val_loss: 0.2729
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9460 - loss: 0.1178 - val_accuracy: 0.9000 - val_loss: 0.2625
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9604 - loss: 0.1108 - val_accuracy: 0.9000 - val_loss: 0.2576
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9640 - loss: 0.1041 - val_accuracy: 0.9000 - val_loss: 0.2606
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9676 - loss: 0.0992 - val_accuracy: 0.9000 - val_loss: 0.2586
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9676 - loss: 0.0958 - val_accuracy: 0.9000 - val_loss: 0.2560
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9748 - loss: 0.0915 - val_accuracy: 0.9000 - val_loss: 0.2572
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9748 - loss: 0.0882 - val_accuracy: 0.9000 - val_loss: 0.2590
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9712 - loss: 0.0862 - val_accuracy: 0.9000 - val_loss: 0.2584
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9748 - loss: 0.0834 - val_accuracy: 0.9000 - val_loss: 0.2585
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0813 - val_accuracy: 0.9000 - val_loss: 0.2587
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0784 - val_accuracy: 0.9000 - val_loss: 0.2614
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9748 - loss: 0.0790 - val_accuracy: 0.9000 - val_loss: 0.2639
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9820 - loss: 0.0759 - val_accuracy: 0.9000 - val_loss: 0.2553
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9820 - loss: 0.0748 - val_accuracy: 0.9000 - val_loss: 0.2601
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9748 - loss: 0.0757 - val_accuracy: 0.9000 - val_loss: 0.2595
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9820 - loss: 0.0726 - val_accuracy: 0.9143 - val_loss: 0.2635
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0716 - val_accuracy: 0.9143 - val_loss: 0.2627
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9820 - loss: 0.0724 - val_accuracy: 0.9143 - val_loss: 0.2641
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0709 - val_accuracy: 0.9143 - val_loss: 0.2627
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9784 - loss: 0.0697 - val_accuracy: 0.9143 - val_loss: 0.2675
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9820 - loss: 0.0695 - val_accuracy: 0.9000 - val_loss: 0.2652
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9748 - loss: 0.0679 - val_accuracy: 0.9143 - val_loss: 0.2676
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9820 - loss: 0.0676 - val_accuracy: 0.9143 - val_loss: 0.2653
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9820 - loss: 0.0654 - val_accuracy: 0.9143 - val_loss: 0.2674
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0661 - val_accuracy: 0.9143 - val_loss: 0.2714
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9784 - loss: 0.0662 - val_accuracy: 0.9143 - val_loss: 0.2712
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9784 - loss: 0.0648 - val_accuracy: 0.9143 - val_loss: 0.2694
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9784 - loss: 0.0644 - val_accuracy: 0.9143 - val_loss: 0.2686
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0642 - val_accuracy: 0.9143 - val_loss: 0.2697
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0643 - val_accuracy: 0.9143 - val_loss: 0.2692
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0622 - val_accuracy: 0.9143 - val_loss: 0.2680
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0628 - val_accuracy: 0.9143 - val_loss: 0.2742
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0606 - val_accuracy: 0.9143 - val_loss: 0.2709
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9784 - loss: 0.0613 - val_accuracy: 0.9143 - val_loss: 0.2721
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9784 - loss: 0.0615 - val_accuracy: 0.9143 - val_loss: 0.2724
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9784 - loss: 0.0605 - val_accuracy: 0.9143 - val_loss: 0.2747
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9784 - loss: 0.0607 - val_accuracy: 0.9143 - val_loss: 0.2710
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9784 - loss: 0.0591 - val_accuracy: 0.9143 - val_loss: 0.2765
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9784 - loss: 0.0600 - val_accuracy: 0.9143 - val_loss: 0.2726
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9784 - loss: 0.0606 - val_accuracy: 0.9143 - val_loss: 0.2757
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9784 - loss: 0.0599 - val_accuracy: 0.9143 - val_loss: 0.2793

# %% [markdown]
# ### 7. Model Evaluation

# %% [markdown]
# 1. First, apply the same preprocessing you did to train set to test set also

# %%
# WRITE YOUR CODE HERE
loss_train, acc_train = model.evaluate(x_train_np, y_train_num, verbose=0)
print('Accuracy (Train): {:.2f}%'.format(acc_train * 100))
print('Loss (Train): {:.4f}'.format(loss_train))
# Out:
# Accuracy (Train): 96.55%
# Loss (Train): 0.1014

# %% [markdown]
# 2. Evaluate the model, print final accuracy and loss

# %%
# WRITE YOUR CODE HERE
# Accuracy min ~96%

loss_test, acc_test = model.evaluate(x_test_np, y_test_num, verbose=0)
print('Accuracy (Test): {:.2f}%'.format(acc_test * 100))
print('Loss (Test): {:.4f}'.format(loss_test))
# Out:
# Accuracy (Test): 97.70%
# Loss (Test): 0.0648

# %% [markdown]
# 3. Plot loss and validation loss depending on the training epochs into one graph. In another graph, plot accuracy and validation accuracy

# %%
# WRITE YOUR CODE HERE
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
