# %% [markdown]
# # MPA-MLF, Lab 6 - Feedforward Neural Networks with regularization techniques and hyperparameter tunning

# %% [markdown]
# ## Exercise 1 - Classification of an images

# %% [markdown]
# The goal of this task will be to create Multi-layer perceptron model, that is able to recognize the  CIFAR10 dataset (https://www.cs.toronto.edu/~kriz/cifar.html). The CIFAR10 dataset consist of 60000 images with resolution of 32x32 pixels. There are 10 classes in total - *airplane*, *automobile*, *bird*, *cat*, *deer*, *dog*, *frog*, *horse*, *ship*, *truck*

# %% [markdown]
# These is an example of the dataset:

# %% [markdown]
# ![cifar10.png](data:image/png;base64,...)

# %% [markdown]
# ### 0. Import libraries

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.optimizers import SGD
from keras.datasets import cifar10
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import cv2

font = {'weight' : 'bold',
        'size'   : 12}

matplotlib.rc('font', **font)

# %% [markdown]
# ### 1. Load the Dataset
# The dataset is already a part of the Keras library, so we can quickly load it using the following command

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 18s 0us/step

# %% [markdown]
# The following numbered labels represent the labels in the dataset:

# %%
labels = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}

# %% [markdown]
# ### 2. Data Examination

# %% [markdown]
# Fistly, lets have a look and the couple of images we have,

# %%
def display_random_images(x_data: np.array, y_data: np.array, count: int = 10) -> None:
  index = np.array(len(x_data))
  selected_ind = np.random.choice(index, count)

  selected_img = x_data[selected_ind]
  selected_labels_encoded = y_data[selected_ind]
  selected_labels = [labels[x[0]] for x in selected_labels_encoded]

  concat_img = np.concatenate(selected_img, axis=1)

  plt.figure(figsize=(20,10))
  plt.imshow(concat_img)

  for id_label, label in enumerate(selected_labels):
    plt.text((32/2) + 32*id_label - len(label), 32*(5/4), label)
  plt.axis('off')
  plt.show()

# %%
display_random_images(X_train, y_train)

# %%
#check the shape of image dataset

X_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# In our dataset, we have 60000 images with 32x32 resolution. Each image has three channels (R, G, B). We have 50000 images for training and 10000 images for testing. Each channel for each image has values from 0 - 255, where each number represents the pixel intensity.
# With the combination of intensities of R, G and B, you can display up to 16,777,216 different colours (256^3)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here you can display each channel separately:

# %%
def display_channels_separately(image: np.array) -> None:

  plt.figure()
  fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(10, 5))


  axs[0].imshow(image[:,:,0],cmap='Reds')
  axs[1].imshow(image[:,:,1],cmap='Blues')
  axs[2].imshow(image[:,:,2],cmap='Greens')

  axs[3].imshow(image)

  plt.show()

# %%
display_channels_separately(X_train[0])

# %% [markdown]
# ### 3. Preprocessing of the images

# %% [markdown]
# For machine learning purposes, we have to preprocess our images. Firstly we need to scale our images, to scale intensity values from 0-1 (min-max scaling)

# %%
X_train_scaled = X_train.astype('float32') / 255.0

# %% [markdown]
# We need to one-hot-encode the labels in our ground truth variable as our second preprocessing.

# %%
y_train_encoded = to_categorical(y_train, num_classes=10)

# %% [markdown]
# ### 4. Define the model architecture

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(128, activation='sigmoid'))
model.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# We will define *the Sequential* model as in our last exercise. This time we will use a different approach to determine the input layers. Instead of specifying the *input_dim* parameter in our first hidden layer, we will create a **Flatten** layer that takes our 32x32x3 image and reshapes it into 1x3072.
#
# We will specify ten neurons in our output layer because we have 10 possible outputs and a **softmax** activation function that returns us a probability distribution over the classes. The class with the highest probability is typically chosen as the predicted class for a given input.

# %% [markdown]
# Check the description of our model:

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       393,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 394,634 (1.51 MB)
#  Trainable params: 394,634 (1.51 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# The next step is to compile our model, we will use *categorical_crossentropy* as a loss function, *stochastic gradient descend* as an optimisation and we will be checking *the accuracy* metric.

# %%
optimizer = SGD(learning_rate = 0.001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# ### 5. Train the model

# %% [markdown]
# Our model will be trained in the same way as in our last pc_labs,

# %%
history = model.fit(X_train_scaled, y_train_encoded, epochs=20, batch_size=128, validation_split = 0.2)
# Out:
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.1125 - loss: 2.3147 - val_accuracy: 0.1464 - val_loss: 2.2769
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1706 - loss: 2.2611 - val_accuracy: 0.1956 - val_loss: 2.2485
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2089 - loss: 2.2351 - val_accuracy: 0.2263 - val_loss: 2.2239
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2345 - loss: 2.2121 - val_accuracy: 0.2451 - val_loss: 2.2025
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2502 - loss: 2.1914 - val_accuracy: 0.2562 - val_loss: 2.1830
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2650 - loss: 2.1727 - val_accuracy: 0.2659 - val_loss: 2.1654
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2749 - loss: 2.1558 - val_accuracy: 0.2725 - val_loss: 2.1496
# Epoch 8/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2811 - loss: 2.1403 - val_accuracy: 0.2790 - val_loss: 2.1349
# Epoch 9/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2887 - loss: 2.1263 - val_accuracy: 0.2838 - val_loss: 2.1219
# Epoch 10/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2907 - loss: 2.1135 - val_accuracy: 0.2913 - val_loss: 2.1099
# Epoch 11/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2983 - loss: 2.1017 - val_accuracy: 0.2948 - val_loss: 2.0986
# Epoch 12/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3002 - loss: 2.0909 - val_accuracy: 0.2990 - val_loss: 2.0887
# Epoch 13/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3015 - loss: 2.0808 - val_accuracy: 0.3018 - val_loss: 2.0792
# Epoch 14/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3059 - loss: 2.0716 - val_accuracy: 0.3055 - val_loss: 2.0703
# Epoch 15/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3092 - loss: 2.0628 - val_accuracy: 0.3066 - val_loss: 2.0620
# Epoch 16/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3088 - loss: 2.0545 - val_accuracy: 0.3097 - val_loss: 2.0544
# Epoch 17/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3142 - loss: 2.0468 - val_accuracy: 0.3115 - val_loss: 2.0470
# Epoch 18/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3151 - loss: 2.0394 - val_accuracy: 0.3081 - val_loss: 2.0398
# Epoch 19/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3148 - loss: 2.0324 - val_accuracy: 0.3154 - val_loss: 2.0335
# Epoch 20/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3178 - loss: 2.0258 - val_accuracy: 0.3158 - val_loss: 2.0275

# %% [markdown]
# ### 6. Model evaluation

# %%
X_test = X_test.astype('float32') / 255.0
y_test_encoded = to_categorical(y_test, num_classes=10)

# %%
score = model.evaluate(X_test, y_test_encoded, verbose=0)
print('Test loss:', score[0])
print(f'Test accuracy: {score[1]*100} %')
# Out:
# Test loss: 2.0250508785247803
# Test accuracy: 31.610000133514404 %

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %% [markdown]
# As you can see from the evaluation above, we was able to achive approx. 30% of an accuracy. In other word approx. 70% of an images we classified wrongly. That is really bad!

# %% [markdown]
# Lets check the best predictions from our model:

# %%
def show_the_best_predictions(model, x_test: np.array, y_test: np.array, n_of_pred: int = 10) -> None:
  mapping = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}

  predictions = model.predict(x_test)
  y_test = y_test.reshape(1,-1)
  predictions_ind = np.argmax(predictions, axis=1)
  predictions_ind = predictions_ind.reshape(1, -1)

  corect_predictions = np.where(predictions_ind == y_test)

  rows_correct = corect_predictions[1]
  predictedtions_correct = predictions[rows_correct]
  target_correct = y_test[0][rows_correct]

  max_samples = predictions[rows_correct, target_correct]
  selected_images = x_test[rows_correct]
  sorted_ind = np.argsort(max_samples)[::-1]


  images = []
  prob = []
  labels = []


  for ind in range(n_of_pred):

    index = sorted_ind[ind]

    labels.append(target_correct[index])
    prob.append(max_samples[index])
    images.append(selected_images[index])

  plt.figure(figsize=(20,10))

  images = np.concatenate(np.asarray(images),axis=1)
  plt.imshow(images)
  for ins in range(n_of_pred):
    texts = '{}: \n{:.3f} %'.format(mapping[labels[ins]], prob[ins]*100)
    plt.text((32/2) + 32*ins - len(mapping[labels[ins]]), 32*(5/4), texts)

  plt.axis('off')
  plt.show()

# %%
show_the_best_predictions(model, X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# ### Task Description:

# %% [markdown]
# You task of this exercise would be to improve the model's performance to achieve better results in image classification task. There is no need to change the preprocessing of the dataset. There are possible way how to improve the models performance:

# %% [markdown]
# 1. Hyperparameter tunning - change the hyperparameters so that the model will perform better. You can experiment with the following:
#  - *changing the number of neurons in the hidden layer*
#  - *changing the number of hidden layers*
#  - *changing the activation functions*
#  - *changing the learning rate*
#  - *changing the optimizer* - So far, we have used only Gradient descend as our optimizer, but Keras offers other algorithms that can perform better - check the documentation!
#  - *changing the number of learning epochs*\
#  - *changing the batch size*
#
# 2. Regularization techniques - There are several regularization techniques that can improve the model's performance:
#  - *Dropout* -  In the Keras lib. you can add *dropout layer* into your Sequential model using the following command  *model.add(Dropout(p))* where *p* is an hyperparameter that controls dropout probabily, typical values are 0.1 - 0.5.
#  - *L1, L2 regularization* - In keras the regularization is applied for selected layers, there is an example how to add l2 regularization to an layer (for more details check the documnetation):  *model.add(Dense(64, activation='relu', input_dim=100, kernel_regularizer=l2(0.01)))*
#  - *Early stopping* -  In Keras, you can use the EarlyStopping callback to implement early stopping in your model. *early_stopping = EarlyStopping(monitor='val_loss', patience=3)*,  *model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val), callbacks=[early_stopping])*

# %% [markdown]
# Try to make the highest testing accuracy possible. You can directly edit the code that is presented above, or you can copy everything into new cells. Please submit only the code with the best performance and briefly describe what approaches you have tried and what were the results

# %% [markdown]
# ### WRITE YOUR DESCRIPTION IN THIS CELL ###
#
# I improved the MLP model by switching from the SGD optimizer to Adam and replacing Sigmoid activation with ReLU. I increased the network's capacity with two hidden layers (512 and 256 neurons). To avoid overfitting, I integrated dropout layers (0.2 and 0.1). These modifications improved the accuracy from 31% to 47.78%.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
labels = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}

X_train_scaled = X_train.astype('float32') / 255.0
X_test_scaled = X_test.astype('float32') / 255.0

y_train_encoded = to_categorical(y_train.flatten(), num_classes=10)
y_test_encoded = to_categorical(y_test.flatten(), num_classes=10)

indices = np.random.permutation(len(X_train_scaled))
X_train_scaled = X_train_scaled[indices]
y_train_encoded = y_train_encoded[indices]

# %%
from tensorflow.keras.layers import Dropout

model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.1))

model.add(Dense(10, activation='softmax'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3699/616270185.py in <cell line: 0>()
#       1 from tensorflow.keras.layers import Dropout
# ----> 2 from tensorflow.keras.optimizer import Adam
#       3
#       4 model = Sequential()
#       5 model.add(Flatten(input_shape=(32, 32, 3)))
#
# ModuleNotFoundError: No module named 'tensorflow.keras.optimizer'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │     1,573,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,707,274 (6.51 MB)
#  Trainable params: 1,707,274 (6.51 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow as tf

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

history = model.fit(X_train_scaled, y_train_encoded, epochs=50, batch_size=64, validation_split = 0.2)
# Out:
# Epoch 1/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.2768 - loss: 1.9753 - val_accuracy: 0.3478 - val_loss: 1.8169
# Epoch 2/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3264 - loss: 1.8381 - val_accuracy: 0.3612 - val_loss: 1.7832
# Epoch 3/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3496 - loss: 1.7777 - val_accuracy: 0.3822 - val_loss: 1.7089
# Epoch 4/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3678 - loss: 1.7394 - val_accuracy: 0.4018 - val_loss: 1.6749
# Epoch 5/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3772 - loss: 1.7090 - val_accuracy: 0.4083 - val_loss: 1.6706
# Epoch 6/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3857 - loss: 1.6914 - val_accuracy: 0.4091 - val_loss: 1.6401
# Epoch 7/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3905 - loss: 1.6783 - val_accuracy: 0.4147 - val_loss: 1.6411
# Epoch 8/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3936 - loss: 1.6643 - val_accuracy: 0.4303 - val_loss: 1.6276
# Epoch 9/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4023 - loss: 1.6502 - val_accuracy: 0.4239 - val_loss: 1.6234
# Epoch 10/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4040 - loss: 1.6382 - val_accuracy: 0.4401 - val_loss: 1.5923
# Epoch 11/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4102 - loss: 1.6250 - val_accuracy: 0.4127 - val_loss: 1.6322
# Epoch 12/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4143 - loss: 1.6198 - val_accuracy: 0.4514 - val_loss: 1.5687
# Epoch 13/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.
100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4892 - loss: 1.4149 - val_accuracy: 0.4720 - val_loss: 1.5030
# Epoch 76/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4926 - loss: 1.4090 - val_accuracy: 0.4741 - val_loss: 1.4847
# Epoch 77/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4912 - loss: 1.4176 - val_accuracy: 0.4803 - val_loss: 1.4768
# Epoch 78/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4936 - loss: 1.4044 - val_accuracy: 0.4819 - val_loss: 1.4643
# Epoch 79/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4895 - loss: 1.4158 - val_accuracy: 0.4815 - val_loss: 1.4628
# Epoch 80/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4899 - loss: 1.4127 - val_accuracy: 0.4761 - val_loss: 1.4830
# Epoch 81/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4931 - loss: 1.3999 - val_accuracy: 0.4814 - val_loss: 1.4765
# Epoch 82/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4959 - loss: 1.3995 - val_accuracy: 0.4746 - val_loss: 1.4915
# Epoch 83/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4910 - loss: 1.4046 - val_accuracy: 0.4862 - val_loss: 1.4718
# Epoch 84/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4938 - loss: 1.4033 - val_accuracy: 0.4813 - val_loss: 1.4811
# Epoch 85/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4954 - loss: 1.4005 - val_accuracy: 0.4801 - val_loss: 1.4724
# Epoch 86/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4988 - loss: 1.3946 - val_accuracy: 0.4741 - val_loss: 1.4877
# Epoch 87/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4980 - loss: 1.3928 - val_accuracy: 0.4795 - val_loss: 1.4711
# Epoch 88/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4976 - loss: 1.3947 - val_accuracy: 0.4816 - val_loss: 1.4724
# Epoch 89/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4989 - loss: 1.3885 - val_accuracy: 0.4763 - val_loss: 1.4678
# Epoch 90/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4992 - loss: 1.3938 - val_accuracy: 0.4714 - val_loss: 1.4985
# Epoch 91/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4967 - loss: 1.3909 - val_accuracy: 0.4866 - val_loss: 1.4633
# Epoch 92/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4980 - loss: 1.3856 - val_accuracy: 0.4844 - val_loss: 1.4644
# Epoch 93/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5001 - loss: 1.3876 - val_accuracy: 0.4742 - val_loss: 1.4846
# Epoch 94/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5001 - loss: 1.3828 - val_accuracy: 0.4827 - val_loss: 1.4881
# Epoch 95/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4972 - loss: 1.3859 - val_accuracy: 0.4720 - val_loss: 1.4808
# Epoch 96/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5003 - loss: 1.3821 - val_accuracy: 0.4779 - val_loss: 1.4793
# Epoch 97/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5009 - loss: 1.3837 - val_accuracy: 0.4734 - val_loss: 1.4764
# Epoch 98/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4994 - loss: 1.3851 - val_accuracy: 0.4706 - val_loss: 1.5034
# Epoch 99/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4995 - loss: 1.3848 - val_accuracy: 0.4691 - val_loss: 1.4779
# Epoch 100/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4981 - loss: 1.3885 - val_accuracy: 0.4704 - val_loss: 1.4852

# %%
score = model.evaluate(X_test_scaled, y_test_encoded, verbose=0)

print(f'\nTest loss: {score[0]:.4f}')
print(f'Test accuracy: {score[1]*100:.2f} %')
# Out:
# Test loss: 1.4903
# Test accuracy: 47.78 %

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
show_the_best_predictions(model, X_test_scaled, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ### Voluntary task:
# Implement one of the hyperparameter tunning algorithms discussed in the lecture, such as *Grid Search*, *Random Search* or more sophisticated ones. Some of these algorithms are already included in the Keras. Check the documentation
